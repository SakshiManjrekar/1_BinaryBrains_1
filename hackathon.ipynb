# %%
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/covid_19_in_education.csv')
type(df)
new_df = df.dropna()
df['submission_date'] = pd.to_datetime(df['submission_date'])
df = df.dropna(axis='columns')
df.head()
df.info()
sns.displot(df['gender'],color='pink', height=8)
sns.displot(df['age'],color='green', height=12)
sns.displot(df['geography'], height=12)
sns.jointplot(df['can_children_observe_deterioration_of_basic_services_of_school'],df['do_children_3_and_17_yrs_receive_regular_school_meals'])
sns.displot(df['are_there_teachers_at_scheduled_class_hours'],color='orange', height=8)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4436 entries, 0 to 4435
# Data columns (total 12 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   submission_id                                                   4436 non-null   float64
#  1   submission_date                                                 4436 non-null   datetime64[ns]
#  2   gender                                                          4436 non-null   object
#  3   age                                                             4436 non-null   object
#  4   geography                                                       4436 non-null   object
#  5   financial_situation                                             4436 non-null   object
#  6   education                                                       4436 non-null   object
# ...
